# %% [markdown]
# # Assad Ullah Khan

# %% [markdown]
# # Reg No = 0526

# %% [markdown]
# # Lab Report Tasks

# %%
import math

class Circle:

    def __init__(self, radius: float = 1) -> None:
        if radius <= 0:
            raise ValueError("Radius must be positive.")
        self._radius = radius

    @property
    def radius(self) -> float:
        return self._radius

    @radius.setter
    def radius(self, value: float) -> None:
        if value <= 0:
            raise ValueError("Radius must be positive.")
        self._radius = value

    def cylinder_volume(self, height: float) -> float:
        if height <= 0:
            raise ValueError("Height must be positive.")
        return self.area * height

    @property
    def area(self) -> float:
        return math.pi * self._radius**2

    @property
    def circumference(self) -> float:
        return 2 * math.pi * self._radius

    @property
    def diameter(self) -> float:
        return 2 * self._radius

    def __repr__(self) -> str:
        return f"Circle(radius={self._radius})"

    def __str__(self) -> str:
        return f"Circle with radius: {self._radius}"

    @staticmethod
    def calculate_area_from_radius(radius: float) -> float:
        if radius <= 0:
            raise ValueError("Radius must be positive.")
        return math.pi * radius**2

    @classmethod
    def from_diameter(cls, diameter: float) -> 'Circle':
        if diameter <= 0:
            raise ValueError("Diameter must be positive.")
        radius = diameter / 2
        return cls(radius)


# Example Usage
circle1 = Circle(5)
print(circle1)
print(f"Area: {circle1.area}")
print(f"Circumference: {circle1.circumference}")
print(f"Diameter: {circle1.diameter}")

# Using the static method
area_from_radius = Circle.calculate_area_from_radius(7)
print(f"Area calculated using static method (radius=7): {area_from_radius}")

# Using the class method
circle2 = Circle.from_diameter(10)
print(circle2)
print(f"Radius from diameter: {circle2.radius}")

#Using Properties
circle1.radius = 8
print(circle1)
print(f"Area: {circle1.area}")
# Out:
# Circle with radius: 5
# Area: 78.53981633974483
# Circumference: 31.41592653589793
# Diameter: 10
# Area calculated using static method (radius=7): 153.93804002589985
# Circle with radius: 5.0
# Radius from diameter: 5.0
# Circle with radius: 8
# Area: 201.06192982974676

# %%
# a. Define inst_1 and pass a number.
inst_1 = Circle(5)

# b. Make another instance inst_2.
inst_2 = Circle()  # Using default radius

# c. Print inst_1 and inst_2.
print(inst_1)
print(inst_2)

# d. Demonstrate property, staticmethod, and classmethod
print("Demonstrating Properties:")
print(f"inst_1's radius: {inst_1.radius}")  # Get radius using property
inst_1.radius = 7  # Set radius using property setter
print(f"inst_1's new radius: {inst_1.radius}")
print(f"inst_1's area: {inst_1.area}") #Get area using property

print("\nDemonstrating Static Method:")
area_static = Circle.calculate_area_from_radius(6)
print(f"Area calculated with static method: {area_static}")

print("\nDemonstrating Class Method:")
inst_3 = Circle.from_diameter(12)
print(f"inst_3 (created from diameter): {inst_3}")
print(f"inst_3's radius: {inst_3.radius}")

# e. Call __dict__ by the class name.
print("\nClass __dict__:")
print(Circle.__dict__)

# f. Pass the class name to vars().
print("\nvars(Class):")
print(vars(Circle))

# g. Call __dict__ on the object.
print("\ninst_1 __dict__:")
print(inst_1.__dict__)

# h. Pass the class name to help().
print("\nhelp(Class):")
help(Circle)

# i. Print docstrings and annotations
print("\nDocstrings and Annotations:")
print("Class Docstring:", Circle.__doc__)
print("__init__ Docstring:", Circle.__init__.__doc__)
print("__init__ Annotations:", Circle.__init__.__annotations__)
print("radius Docstring:", Circle.radius.__doc__)
print("radius Annotations:", Circle.radius.__annotations__)
print("cylinder_volume Docstring:", Circle.cylinder_volume.__doc__)
print("cylinder_volume Annotations:", Circle.cylinder_volume.__annotations__)
print("area Docstring:", Circle.area.__doc__)
print("area Annotations:", Circle.area.__annotations__)
print("circumference Docstring:", Circle.circumference.__doc__)
print("circumference Annotations:", Circle.circumference.__annotations__)
print("diameter Docstring:", Circle.diameter.__doc__)
print("diameter Annotations:", Circle.diameter.__annotations__)
print("__repr__ Docstring:", Circle.__repr__.__doc__)
print("__repr__ Annotations:", Circle.__repr__.__annotations__)
print("__str__ Docstring:", Circle.__str__.__doc__)
print("__str__ Annotations:", Circle.__str__.__annotations__)
print("calculate_area_from_radius Docstring:", Circle.calculate_area_from_radius.__doc__)
print("calculate_area_from_radius Annotations:", Circle.calculate_area_from_radius.__annotations__)
print("from_diameter Docstring:", Circle.from_diameter.__doc__)
print("from_diameter Annotations:", Circle.from_diameter.__annotations__)

# j. Modify __init__ with default parameters and verify.
inst_4 = Circle()      # Uses default radius = 1
inst_5 = Circle(10)   # Uses radius = 10
print("\nInstances with default and specified radius:")
print(inst_4)
print(inst_5)
# Out:
# Circle with radius: 5
# Circle with radius: 1
# Demonstrating Properties:
# inst_1's radius: 5
# inst_1's new radius: 7
# inst_1's area: 153.93804002589985
#
# Demonstrating Static Method:
# Area calculated with static method: 113.09733552923255
#
# Demonstrating Class Method:
# inst_3 (created from diameter): Circle with radius: 6.0
# inst_3's radius: 6.0
#
# Class __dict__:
# ...
